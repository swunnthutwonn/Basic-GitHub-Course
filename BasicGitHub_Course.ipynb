# %% [markdown]
# # Basic GitHub Course

# %% [markdown]
# ## Introduction to Version Control System

# %% [markdown]
# ### Lecture

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('DB_MEZZdiIs')

# %% [markdown]
# ### Objective

# %% [markdown]
# * What is Git?<br/>
#     Git is a version control system of software.
# <br/>
#
# * What is version contorl?<br/>
#     * Version control system is tracking and managing changes in computer files<br/>
#     * Note :: Computer files ဟုဆိုရာတွင် ကွန်ပျူတာ တစ်လုံးအတွင်းရှိ ဖိုင်မျိုးအစား အကုန်ကို ဆိုလိုသည်။ ဥပမာ စာစီရိုက်ပြုလုပ်ထားသော Word ဖိုင်များ၊ စာရင်းအင်းပြုလုပ်ထားသော Excel ဖိုင်များမှသည် ပရိုဂရမ်ရေးသားထားသော Coding ဖိုင်များအားလုံး အကျုံးဝင်သည်။
#
# <br/>
#
# * Benefits of Version Control System
#     * Collaborate work between different users
#     * Track who made changes
#     * What are the changes
#     * When changes are made
#     * Revert back the changes (if needeed)
#     * Store in local & remote repository (eg. Github)
#
# <br/>
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ3w5v3NHCaW5Ig1eG2mWbruAG3_rk_4_tJtg&s'/>
# <br/>
# Easy
# Free
# Opensource

# %% [markdown]
# ## Who Should Study Git & GitHub

# %% [markdown]
# ### Lecture

# %%
YouTubeVideo('-_MkMPT752s')

# %% [markdown]
# ### Objective

# %% [markdown]
# * Who should study?
# * Who should use Git?
# * Why should use?
# * How to use?

# %% [markdown]
# #### Who should study or use Git?

# %% [markdown]
# <b>IT Professional</b>
#
# * Programmer
# * Data Science
# * Web Specialist
# * Student
#
# <br/>
#
# <b>Non-IT Professional</b>
#
# * Collaborative Working Enviroment

# %% [markdown]
# #### Why should use?

# %% [markdown]
# <b>Teamwork</b>
# * Version control
# * Backup
# * Recovery
# * many more...
#
#
# <b>Working Alone</b>
# * You may not need it
# * Track management

# %% [markdown]
# #### How to use?

# %% [markdown]
# git => Version Control Software
# <br/>
# GitHub => Hosting service to store files

# %% [markdown]
# ## Git & GitHub Terminology and Commands

# %% [markdown]
# ### Lecture

# %%
YouTubeVideo('i0gipZJcogQ')

# %% [markdown]
# ### Why we should learn terminology?

# %% [markdown]
# * essential to learn the commonly used terms
#     * အသုံးများသော အသုံးအနှုန်းများကို သီးခြားလေ့လာသင့်သည်။
#     <br/><br/>
# * help understand the domain better and faster
#     * မိမိလေ့လာသော အကြောင်းအရာကို ပိုမိုသိကျွမ်း နားလည်စေနိုင်သည်၊
#     <br/><br/>
# * understand with usage rather than dictionary interpretation
#     * အဘိဓာန်ဖွင့်ဆိုမှုအတိုင်း မဟုတ်ဘဲ အသုံးပြုပုံကိုပါ တပါတည်းနားလည်နိုင်သည်။
#     <br/><br/>
# * understand with usage rather than direct translation into own language
#     * တိုက်ရိုက်ဘာသာပြန်ခြင်းထက် အသုံးပေါ်မှုတည်၍ နားလည်နိုင်သည်။

# %% [markdown]
# ### အသုံးများသော စကားလုံးများ (Terminology)

# %% [markdown]
# * Folder / Directory / URL
# * Comand Prompt / Command Line / CLI
# * (Remote) Repository - a folder or a place where your files are stored.
# * Git - Verison Control Software
# * GitHub - web hosting for Git Repository
# * Staging area - temporary location
# * Watch - get notification about a repository whenever there are changes
# * Star - bookmark repository, easy access

# %% [markdown]
# ### အသုံးများသော စကားလုံးများ (Git Commands)

# %% [markdown]
# * git init [repository_name]
#     * <b>Repository</b> တစ်ခု စတင်တည်ဆောက်ရန် အသုံးပြုသည်
# <br/><br/>
# * git clone [url]
#     * အွန်လိုင်းပေါ်ရှိ Repository အားမိမိ၏ ကွန်ပျူတာပေါ်သို့ ကူးယူရန် အသုံးပြုသည်။
# <br/><br/>
# * git add [file]
#     * ဖိုင်တစ်ခု၏ ပြောင်းလဲမှုအား မှတ်မည်ဟုစေခိုင်းကာ Staging area တွင်ထားသည်။
# <br/><br/>
# * git add *
#     * ဖိုင်များအားလုံး၏ ပြောင်းလဲမှုအား မှတ်မည်ဟုစေခိုင်းကာ Staging area တွင်ထားသည်။
# <br/><br/>
# * git reset [file]
#     * Staging area တွင်ထားရှိပြီးသော ဖိုင်အား ပြန်လည်ရုပ်သိမ်းသည်။
#     <br/><br/>
# * git stauts
#     * အတည်ပြုရန်လိုအပ်သော (ပြောင်းလဲမှုပြုထားသော) ဖိုင်များအား ဖော်ပြသည်။
#     <br/><br/>
# * git commit -m "[any_message_about_changes]"
#     * ပြောင်းလဲမှုပြုလုပ်ထားသော ဖိုင်များအား အတည်ပြုမှတ်သားသည်။
#     <br/><br/>
# * git commit -a
#     * add လုပ်ထားသော ဖိုင်များနှင့် ပြောင်းလဲမှုပြုထားသော ဖိုင်များအား အတည်ပြုမှတ်သားသည်။
#     <br/><br/>
# * git push
#     * Remote repository သို့ပြောင်းလဲမှုများအား Upload ပြုလုပ်သည်။
#     <br/><br/>
# * git pull
#     * Remote repository မှ ပြောင်းလဲမှုများအား မိမိကွန်ပျူတာအတွင်းသို့ Download ရယူသည်။

# %% [markdown]
# ## Sign-up on GitHub

# %% [markdown]
# ### Lecture

# %%
YouTubeVideo('c7e5Hcb0JMY')

# %% [markdown]
# * go to google
# * type "github.com"
# * create user account with gmail
# * sign-in
# * create basic-github repository with README.md file
# * add new line "## About this course" in README.md file
# * push commit buttom
# * create about.txt file in basic-github repository
# * add new lin "This text file is about Myanmar Data Science Course".
# * push commit buttom

# %% [markdown]
# ## Git Installation on Window 10

# %% [markdown]
# ### Lecture

# %%
YouTubeVideo('u_k_kUE7Qlc')

# %% [markdown]
# * download and install git as per video
# * command use "git clone basic-github" download in your local computer

# %% [markdown]
# ## Updating file to remote repository

# %% [markdown]
# ### Lecture

# %%
YouTubeVideo('HBYQ8DKvitA')

# %% [markdown]
# * create new text file with the name example.txt in basic-github folder and type "This file is created from local computer."
# * git status
# * git add example.txt
# * git status
# * git commit -m "First Commit"
# * git status
# * git push -u origin main

# %% [markdown]
# ## Creating Git Repository Locally

# %% [markdown]
# ### Lecture

# %%
YouTubeVideo('ExYTyxXvtcg')

# %% [markdown]
# ### Steps
#
# * Local Computer
#     * git init
#     * create folders and files  (staging area)
#     * Push files to Remote Repository (staging area)
#
# * GitHub
#     * GitHub Hosting

# %% [markdown]
# ### Commands as follow

# %% [markdown]
# * <b>create a new repository on the command line</b>
#     * echo "# swunn" >> README.md
#     * git init
#     * git add README.md
#     * git commit -m "first commit"
#     * git branch -M main
#     * git remote add origin https://github.com/swunnthutwonn/local-folder.git
#     * git push -u origin main
# <br/><br/>
# * <b>push an existing repository from the command line</b>
#     * git remote add origin https://github.com/swunnthutwonn/local-folder.git
#     * git branch -M main
#     *git push -u origin main

# %% [markdown]
# ## Understainding .gitignore

# %% [markdown]
# ### Lecture

# %%
YouTubeVideo('ZgTh0EBPPpA')

# %% [markdown]
# ### Steps
#
# * Local Computer
#     * create .gitignore
#     * create files/folder, add to gitignore
#     * add files to staging area

# %% [markdown]
# ### Commands
#
# * touch about.txt
# * touch main.txt
# * touch .gitignore
# * type "This is main text" in main.txt
# * type "This is about text" in about.txt
# * git status
# * type "about.txt" in .gitignore file
# * git add .
# * git status
# * Create floder with name "private" in local-folder
# * Create floder with name "public" in local-folder
# * git status
# * type "/private" in .gitignore file
# * git stauts
# * git commit -m "Ignore Lesson"
# * git push -u origin main

# %% [markdown]
# ## Branching Basic

# %% [markdown]
# ### Lecture

# %%
YouTubeVideo('KTLTDnBa5Rw')

# %% [markdown]
# ### Commands

# %% [markdown]
# * git branch prodcut
# * git checkout product
# * touch myproduct.txt
# * open myprodcut.txt file and type "Something about our products."
# * git add .
# * git commit -  m "added my product"
# * git status
# * git checkout main
# * git merge product
# * git checkout main
# * git checkout product
# * git status

# %% [markdown]
# ## Exploring Github

# %% [markdown]
# ### Lecture

# %%
YouTubeVideo('smX-rhw9Rsc')

# %% [markdown]
# ## Git & Github Use Cases

# %% [markdown]
# ### Lecture

# %%
YouTubeVideo('7U7iy6bI4Ns')

# %% [markdown]
# ### Use Case-1

# %%
from IPython.display import Image
Image('Use_case-1.PNG')

# %% [markdown]
# #### Commands

# %% [markdown]
# * git clone 'Basic-GitHub-Course' from github repositorys
# * create new text file "contact.txt" and type "This file is added on github.com"
# * git pull origin main

# %% [markdown]
# ### Use Case 2

# %%
from IPython.display import Image
Image('Use_case-2.PNG')

# %% [markdown]
# #### Commands

# %% [markdown]
# * modified contact.txt
# * create new file home.txt
# * git status
# * git add .
# * git status
# * git commit -m "Local changes"
# * git push -u origin main

# %% [markdown]
# ### Use Case 3

# %%
from IPython.display import Image
Image('Use_case-3.PNG')

# %% [markdown]
# #### Commands

# %% [markdown]
# * create use-case-3 folder
# * open GIT Bash Here in this folder
# * create testing.txt file in this folder and type "this is a testing file."
# *
